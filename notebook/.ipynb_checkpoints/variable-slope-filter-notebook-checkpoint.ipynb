# %%
import numpy as np
from scipy import signal
from matplotlib import pyplot as plt
from IPython import display

# %%
sample_freq = 44100

hz_conv = (1 / (44100))*np.pi*2

one_second_noise = np.random.rand(1*sample_freq)

# %%
plt.plot(one_second_noise)

# %% [markdown]
# ---
# # Low pass
#
# **Transfer function**
#
# $ F_{lp}(z) = \frac{\alpha}{1 + (\alpha - 1)z^{-1}} $

# %%
def find_alpha(cutoff, sample_freq):
    
    T = 1 / sample_freq

    omega_c = -np.pi * 2 * cutoff * T
    
    alpha = np.cos(omega_c) - 1 + np.sqrt( np.cos(omega_c)**2 - 4*np.cos(omega_c) + 3 )
    
    return alpha

# %%
cutoffs = np.logspace(np.log10(1),np.log10(20000),200)



alphas = find_alpha(cutoffs, 44100)

plt.plot(cutoffs, alphas)
plt.show()

alpha = find_alpha(5000, 44100)
print(alpha)
# Out:
# 0.4954049872818431

# %%
def low_pass_filter(signal, cutoff, sample_freq):
    
    T = 1 / sample_freq
    omega_c = -np.pi * 2 * cutoff * T
    
    alpha = np.cos(omega_c)  - 1 + np.sqrt( np.cos(omega_c)**2 - 4*np.cos(omega_c) + 3 )
    
    output = np.zeros(signal.shape)
    
    for n in range(1,len(signal)):
        output[n] = output[n - 1] + alpha*(signal[n] - output[n-1])
    
    return output

# %%
# my attempt at low pass

sample_freq = 44100

cutoff = 10 # hz

T = 1 / sample_freq

omega_c = np.pi * 2 * cutoff * T

alpha = np.cos(omega_c)  - 1 + np.sqrt( np.cos(omega_c)**2 - 4*np.cos(omega_c) + 3 )


num = [alpha] # numerator
denom = [(alpha-1),1] # denominator

w, mag, phase = signal.bode((num,denom))

w = w * (2 * np.pi)

# filter signal
lp_noise = low_pass_filter(one_second_noise, cutoff, sample_freq)

print("Mean of new signal")
print(np.mean(lp_noise))

# plot results
plt.figure()
plt.title("Low pass cutoff " + str(cutoff) + "hz Bode magnitude plot")
plt.semilogx(w, mag)    # Bode magnitude plot
plt.figure()
plt.title("Low pass cutoff " + str(cutoff) + "hz Bode phase shift plot")
plt.semilogx(w, phase)  # Bode phase plot
plt.show()
# Out:
# Mean of new signal
# 0.49261748907382225

# %%
print("Unfiltered signal")
display.Audio(one_second_noise, rate = sample_freq)
# Out:
# Unfiltered signal
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print("Filtered signal")
display.Audio(lp_noise, rate = sample_freq)
# Out:
# Filtered signal
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ---
# # Inverse low pass
# ---
#
# **Transfer function**
#
# $ F_{invlp}(z) = \frac{1 + (\alpha - 1)z^{-1}}{\alpha} = \frac{z + (\alpha - 1)}{\alpha z}$
#
# **Finding difference equation**
#
# $\frac{Y}{X} = \frac{1 + (\alpha - 1)z^{-1}}{\alpha}$
#
# $ Y = X \frac{1 + (\alpha - 1)z^{-1}}{\alpha} $
#
# $ y[n] = ( x[n] + (\alpha - 1)x[-1] ) \frac{1}{\alpha} $

# %%
# inverse low pass

cutoff = 5000 # hz

T = 1 / sample_freq

omega_c = -np.pi * 2 * cutoff * T

alpha = np.cos(omega_c)  - 1 + np.sqrt( np.cos(omega_c)**2 - 4*np.cos(omega_c) + 3 )


denom = [alpha] 
num = [(alpha-1),1] 

w, mag, phase = signal.bode((num,denom))

# plot results
plt.figure()
plt.title("Inverted low pass cutoff 1000hz Bode magnitude plot")
plt.semilogx(w, mag)    # Bode magnitude plot
plt.figure()
plt.title("Inverted low pass cutoff 1000hz Bode phase shift plot")
plt.semilogx(w, phase)  # Bode phase plot
plt.show()

# %% [markdown]
# ---
# # Series
# ---

# %% [markdown]
# **Transfer function**
#
# $F_{pair}(\alpha,\beta,z) = \frac{\alpha}{1 + (\alpha - 1)z^{-1}} \frac{1 + (\beta - 1)z^{-1}}{\beta}
# 	= \frac{\alpha(1 + (\beta - 1)z^{-1})}{\beta(1 + (\alpha - 1)z^{-1})}
#     =\frac{\alpha + \alpha(\beta - 1)z^{-1}}{\beta + \beta(\alpha - 1)z^{-1}}$
#
# $|F_{pair}(\alpha,\beta,0)| = |\frac{\alpha + \alpha(\beta - 1)}{\beta + \beta(\alpha - 1)}|= |\frac{\alpha \beta}{\alpha \beta}|$ = 1

# %%
# my attempt at low pass inverse low pass series
factors = np.linspace(1.1,40,10)

plt.figure(figsize=(20,10))

for factor in factors:

    cutoff = 500 # hz

    alpha = find_alpha(cutoff, sample_freq)
    beta = find_alpha(cutoff*factor, sample_freq)

    denom = [alpha,alpha*(beta - 1)] 
    num = [beta,beta*(alpha - 1)] 

    w, mag, phase = signal.bode((num,denom))

    # plot results
    #plt.figure()
    #plt.title("Inverted low pass cutoff 1000hz Bode magnitude plot")
    plt.semilogx(w, mag, label = 'factor = ' + str(np.int(factor)))    # Bode magnitude plot
    #plt.figure()
    '''
    plt.title("Inverted low pass cutoff 1000hz Bode phase shift plot")
    plt.semilogx(w, phase)  # Bode phase plot
    plt.show()
    '''

plt.legend()
plt.show()

# %%
def inv_lp_filter_step(x_curr = 0, prev = 0, alpha = 0):
    
    x_prev = prev
    
    output = alpha**(-1)*(x_curr + x_prev*(alpha - 1))
    
    return output

# %%
def lp_filter_step(x_curr = 0, prev = 0, alpha = 0):
    
    y_prev = prev
    
    output = y_prev + alpha*(x_curr - y_prev)
    
    return output

# %%
# test series of difference equations

sample_freq = 44100
bnoise = np.random.rand(1*sample_freq)
    
def variable_slope_filter(waveform, cutoff_hz, freq_diff_ratio, num_filter_pairs):
    
    streams = [None]*(1 + num_filter_pairs*2)
    streams[0] = waveform

    alphas = [0]*num_filter_pairs*2
    
    cutoff = cutoff_hz
    print()
    print("#######################")
    
    for i in range(num_filter_pairs*2):
        print()
        print("FILTER " + str(i))
        print()
        cutoff *= (freq_diff_ratio**i)
        
        print("calculating alpha for " + str(cutoff))
        print()
        alphas[i] = find_alpha(cutoff, sample_freq)
        
        print("alpha is " + str(alphas[i]))
        print()
        
        streams[i + 1] = np.zeros(waveform.shape)
        
    print("#######################")
    print()
    
    prev_sample = 0
    
    for sdx in range(len(waveform) - 1):

        for i in range(num_filter_pairs*2):
            
            if i%2 == 0:
                # extract x_curr of stream i, y_prev from stream i + 1
                filter_func = lp_filter_step
                prev = streams[i + 1][sdx - 1]
            else:
                filter_func = inv_lp_filter_step
                prev = streams[i][sdx - 1]
                
            # extract x_curr of stream i, y_prev from stream i + 1
            output = filter_func(x_curr = streams[i][sdx], 
                                 prev = prev, 
                                 alpha = alphas[i])

            streams[i + 1][sdx] = output
        
        if sdx%sample_freq == 0:
            print(str(sdx//sample_freq) + " second processeced")
    
    return np.array(streams)

# %%
print("running filter")
filtered_noise = variable_slope_filter(ten_seconds_noise, 50, 10, 1)

filtered_noise -= np.min(filtered_noise)
filtered_noise /= np.mean(filtered_noise)
filtered_noise -= np.mean(filtered_noise)

print("streams")
for rdx in range(3):
    filtered_noise -= np.min(filtered_noise)
    filtered_noise /= np.mean(filtered_noise)
    filtered_noise -= np.mean(filtered_noise)

    row = filtered_noise[rdx]
    print(row)
    plt.plot(row)
    
    plt.show()
# Out:
# running filter
#
# #######################
#
# FILTER 0
#
# calculating alpha for 50
#
# alpha is 0.007098448886540111
#
#
# FILTER 1
#
# calculating alpha for 500
#
# alpha is 0.06873166507627336
#
# #######################
#
# 0 second processeced
# streams
# [ 1.00192325 -0.46937784  0.73724662 ... -0.40279863  0.77516072
#  -0.91562883]
# [-0.98578945 -0.98212373 -0.96991887 ... -0.05049327 -0.04463241
#  -1.        ]
# [-0.79324595 -0.93245564 -0.8045511  ... -0.08461998  0.03477838
#  -1.        ]

# %%
print("Unfiltered noise")
display.Audio(ten_seconds_noise, rate = sample_freq)
# Out:
# Unfiltered noise
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print("Filtered noise")
display.Audio(filtered_noise[-1], rate = sample_freq)
# Out:
# Filtered noise
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print("running filter")
filtered_noise = variable_slope_filter(ten_seconds_noise, 5000, 1.2, 1)

filtered_noise -= np.min(filtered_noise)
filtered_noise /= np.mean(filtered_noise)
filtered_noise -= np.mean(filtered_noise)

print("streams")
for rdx in range(3):
    filtered_noise -= np.min(filtered_noise)
    filtered_noise /= np.mean(filtered_noise)
    filtered_noise -= np.mean(filtered_noise)

    row = filtered_noise[rdx]
    print(row)
    plt.plot(row)
    
    plt.show()
    
print("Filtered noise")
display.Audio(filtered_noise[-1], rate = sample_freq)
# Out:
# running filter
#
# #######################
#
# FILTER 0
#
# calculating alpha for 5000.0
#
# alpha is 0.4954049872818431
#
#
# FILTER 1
#
# calculating alpha for 6000.0
#
# alpha is 0.5537992339262557
#
# #######################
#
# 0 second processeced
# streams
# [ 0.44749868 -0.21089767  0.32905784 ... -0.18110396  0.34602413
#  -0.41059168]
# [-0.00454066 -0.10677095  0.10914081 ... -0.04038415  0.15104444
#  -0.44834715]
# [ 0.35303801 -0.47724295  0.58159521 ... -0.41888194  0.61023898
#  -0.44834715]
# Filtered noise
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print("running filter")
filtered_noise = variable_slope_filter(ten_seconds_noise, 5000, 2, 1)

filtered_noise -= np.min(filtered_noise)
filtered_noise /= np.mean(filtered_noise)
filtered_noise -= np.mean(filtered_noise)

print("streams")
for rdx in range(3):
    filtered_noise -= np.min(filtered_noise)
    filtered_noise /= np.mean(filtered_noise)
    filtered_noise -= np.mean(filtered_noise)

    row = filtered_noise[rdx]
    print(row)
    plt.plot(row)
    
    plt.show()
    
print("Filtered noise")
display.Audio(filtered_noise[-1], rate = sample_freq)
# Out:
# running filter
#
# #######################
#
# FILTER 0
#
# calculating alpha for 5000
#
# alpha is 0.4954049872818431
#
#
# FILTER 1
#
# calculating alpha for 10000
#
# alpha is 0.7072807146637246
#
# #######################
#
# 0 second processeced
# streams
# [ 0.9981164  -0.47038686  0.73394308 ... -0.40393426  0.77178509
#  -0.91578927]
# [-0.01012317 -0.2381401   0.24343476 ... -0.09006935  0.33689764
#  -1.        ]
# [ 0.39955298 -0.50205944  0.5519693  ... -0.28437251  0.59402009
#  -1.        ]
# Filtered noise
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Python emulation of C++ real time filter algorithm

# %%
# constants
cut_off = 500
alphas = []
num_filter_pairs = 2
alpha = 0.0
    
output = 0.0
prev_output = 0.0
prev_lp_outputs = np.zeros((num_filter_pairs*2))
prev_inv_inputs = np.zeros((num_filter_pairs*2))
filter_input = 0.0
prev_input = 0.0
channel_shift = 0
sample_freq = 44100

num_channels = 2

# %%
audio_out = []

for spread_factor in [2,4,8,10]:
    print("now using spread factor = " + str(spread_factor))
    ########### constants ###########
    cut_off = 500
    alphas = []
    num_filter_pairs = 2
    alpha = 0.0

    output = 0.0
    prev_output = 0.0
    prev_lp_outputs = np.zeros((num_filter_pairs*2))
    prev_inv_inputs = np.zeros((num_filter_pairs*2))
    filter_input = 0.0
    prev_input = 0.0
    channel_shift = 0
    sample_freq = 44100

    num_channels = 2
    
    ##################################
    
    input_streams = np.random.rand(2,44100)*2 - 1

    output_streams = np.zeros(input_streams.shape)

    # run in separate function in C++ implementation
    for alpha_num in range(num_filter_pairs*2):
            alphas.append(cut_off * spread_factor**alpha_num * (np.pi*2 / sample_freq))


    # filter loop
    for channel in range(num_channels):

        channel_stream = output_streams[channel]

        channel_shift = num_filter_pairs * channel;

        # iterate over samples
        for sample in range(len(channel_stream)):

            for filter_pair in range(num_filter_pairs):

                ##################### LOW PASS SECTION #####################

                # fetch either plugin input or output from end of previous filter pair
                if (filter_pair == 0):

                    filter_input = input_streams[channel,sample]

                else:
                    filter_input = output

                alpha = alphas[filter_pair*2]

                # filter signal
                output = alpha*filter_input + (1 - alpha) * prev_lp_outputs[filter_pair + channel_shift];

                prev_lp_outputs[filter_pair + channel_shift] = output;

                ##################### INVERSE LOW PASS SECTION #####################

                filter_input = output;

                alpha = alphas[filter_pair*2 + 1]

                # filter signal
                output = ( filter_input + (alpha - 1) * prev_inv_inputs[filter_pair + channel_shift] ) / alpha

                prev_inv_inputs[filter_pair + channel_shift] = filter_input


            channel_stream[sample] = output

        output_streams[channel] = channel_stream

    audio_out.append(channel_stream)

#print("Filtered signal")
#display.Audio(output_streams, rate = sample_freq)
# Out:
# now using spread factor = 2
# now using spread factor = 4
# now using spread factor = 8
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:69: RuntimeWarning: overflow encountered in double_scalars
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:58: RuntimeWarning: overflow encountered in double_scalars
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:69: RuntimeWarning: invalid value encountered in double_scalars
# now using spread factor = 10

# %%
print("Unfiltered signal")
display.Audio(input_streams, rate = sample_freq)
# Out:
# Unfiltered signal
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print("Filtered signal spread = 2")
display.Audio(audio_out[0], rate = sample_freq)
# Out:
# Filtered signal spread = 2
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print("Filtered signal spread = 4")
display.Audio(audio_out[1], rate = sample_freq)
# Out:
# Filtered signal spread = 4
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print("Filtered signal spread = 8")
display.Audio(audio_out[2], rate = sample_freq)
# Out:
# Filtered signal spread = 8
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print("Filtered signal spread = 10")
display.Audio(audio_out[3], rate = sample_freq)
# Out:
# Filtered signal spread = 10
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
